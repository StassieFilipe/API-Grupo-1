# %%
import pandas as pd

# %%
data = {'coluna_1':[1.5,2.0,1.7,2.2,1.9],
        'coluna_2':[10.0,12.0,11.5,13.0,11.],
        'coluna_3':[0,1,0,1,0],
        'coluna_4':[1,0,1,0,1],
        'coluna_5':[20.5,25.5,22.0,27.0,23.0]}

# %%
df = pd.DataFrame(data)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/My Drive/API/COMEXSTAT/'

# %%
exp23_mun = origem + 'EXP_2023_MUN.csv'
imp23mun = origem + 'IMP_2023_MUN.csv'
exp24_mun = origem + 'EXP_2024_MUN.csv'
imp24mun = origem + 'IMP_2024_MUN.csv'
exp25_mun = origem + 'EXP_2025_MUN.csv'
imp25mun = origem + 'IMP_2025_MUN.csv'
ufmun = origem + 'UF_MUN.csv'
exppais = origem + 'PAIS.csv'
sh4 = origem +'SH4.csv'

# %%
exp23_mun = pd.read_csv(exp23_mun,low_memory=False,sep=';',encoding='latin1')
imp23mun = pd.read_csv(imp23mun,low_memory=False,sep=';',encoding='UTF-8')
exp24_mun = pd.read_csv(exp24_mun,low_memory=False,sep=';',encoding='UTF-8')
imp24mun = pd.read_csv(imp24mun,low_memory=False,sep=';',encoding='UTF-8')
exp25_mun = pd.read_csv(exp25_mun,low_memory=False,sep=';',encoding='UTF-8')
imp25mun = pd.read_csv(imp25mun,low_memory=False,sep=';',encoding='UTF-8')
exppais = pd.read_csv(exppais,low_memory=False,sep=';',encoding='latin1')
ufmun = pd.read_csv(ufmun,low_memory=False,sep=';',encoding='latin1')
sh4 = pd.read_csv(sh4,low_memory=False,sep=';',encoding='latin1')

# %%
imp_final = pd.concat([imp23mun,imp24mun,imp25mun],ignore_index=True)
imp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4550156 entries, 0 to 4550155
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
# dtypes: int64(7), object(1)
# memory usage: 277.7+ MB

# %%
exp_final = pd.concat([exp23_mun,exp24_mun,exp25_mun],ignore_index=True)
exp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050346 entries, 0 to 3050345
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   SH4         int64
#  3   CO_PAIS     int64
#  4   SG_UF_MUN   object
#  5   CO_MUN      int64
#  6   KG_LIQUIDO  int64
#  7   VL_FOB      int64
# dtypes: int64(7), object(1)
# memory usage: 186.2+ MB

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB
# 0    2023      10  2209      127        BA  2919553          36      53
# 1    2023      11  4009      493        SP  3456701         473   14008
# 2    2023      11  8536      365        SP  3438709           2     181
# 3    2023       8  8512       63        RJ  3304201       15627  239105
# 4    2023       6  1902      580        PR  4118204         287     368

# %%
exp_final.tail(5)
# Out:
#          CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB
# 3050341    2025       3   713      580        BA  2927408           5      37
# 3050342    2025       6  8708      244        SP  3418800         984   20055
# 3050343    2025       5  7208      386        SP  3448500         215    1613
# 3050344    2025       7   713      741        MT  5102637       50000   42500
# 3050345    2025       1  6506       97        SC  4202305           2     116

# %%
exp_final = exp_final.merge(exppais[['CO_PAIS','NO_PAIS']],on='CO_PAIS',how='left')

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0    2023      10  2209      127        BA  2919553          36      53
# 1    2023      11  4009      493        SP  3456701         473   14008
# 2    2023      11  8536      365        SP  3438709           2     181
# 3    2023       8  8512       63        RJ  3304201       15627  239105
# 4    2023       6  1902      580        PR  4118204         287     368
#
#       NO_PAIS
# 0  Cabo Verde
# 1      México
# 2   Indonésia
# 3   Argentina
# 4      Panamá

# %%
exp_final = exp_final.merge(ufmun[['CO_MUN','NO_MUN']],on='CO_MUN',how='left')

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0    2023      10  2209      127        BA  2919553          36      53
# 1    2023      11  4009      493        SP  3456701         473   14008
# 2    2023      11  8536      365        SP  3438709           2     181
# 3    2023       8  8512       63        RJ  3304201       15627  239105
# 4    2023       6  1902      580        PR  4118204         287     368
#
#       NO_PAIS                  NO_MUN
# 0  Cabo Verde  LUIS EDUARDO MAGALHAES
# 1      México                 VINHEDO
# 2   Indonésia              PIRACICABA
# 3   Argentina                 RESENDE
# 4      Panamá               PARANAGUA

# %%
exp_final = exp_final.merge(sh4[['CO_SH4','NO_SH6_POR']],left_on='SH4',right_on='CO_SH4',how='left')

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO  VL_FOB  \
# 0    2023      10  2209      127        BA  2919553          36      53
# 1    2023      11  4009      493        SP  3456701         473   14008
# 2    2023      11  4009      493        SP  3456701         473   14008
# 3    2023      11  4009      493        SP  3456701         473   14008
# 4    2023      11  4009      493        SP  3456701         473   14008
#
#       NO_PAIS                  NO_MUN  CO_SH4  \
# 0  Cabo Verde  LUIS EDUARDO MAGALHAES    2209
# 1      México                 VINHEDO    4009
# 2      México                 VINHEDO    4009
# 3      México                 VINHEDO    4009
# 4      México                 VINHEDO    4009
#
#                                           NO_SH6_POR
# 0  Vinagres e sucedâneos obtidos a partir do ácid...
# 1  Tubo de borracha vulcanizada, não endurecido, ...
# 2  Tubos de borracha vulcanizada não endurecida, ...
# ...

# %%
exp_final.to_csv(origem+'exp_final.csv',index=False)

# %%
exp_final.to_csv(origem+'exp_final1.csv',index=False)
